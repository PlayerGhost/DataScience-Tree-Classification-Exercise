# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict

# %%
dados = pd.read_csv("Tree-Classification.csv")

dados = dados.sample(frac=1)

dados
# Out:
#             x         y Target
# 391  0.760488  0.556318     C2
# 169  0.286307  0.425160     C1
# 446  0.730982  0.466134     C2
# 67   0.312020  0.639116     C1
# 192  0.472681  0.832230     C1
# ..        ...       ...    ...
# 264  0.349868  0.636440     C1
# 43   0.447918  0.852691     C1
# 581  0.667438  0.216284     C2
# 701  0.750556  0.952266     C2
# 707  0.771319  0.721469     C2
#
# [752 rows x 3 columns]

# %%
y = dados["Target"]

X = dados.drop(columns=["Target"])

print(X)
y
# Out:
#             x         y
# 391  0.760488  0.556318
# 169  0.286307  0.425160
# 446  0.730982  0.466134
# 67   0.312020  0.639116
# 192  0.472681  0.832230
# ..        ...       ...
# 264  0.349868  0.636440
# 43   0.447918  0.852691
# 581  0.667438  0.216284
# 701  0.750556  0.952266
# 707  0.771319  0.721469
#
# [752 rows x 2 columns]
# 391    C2
# 169    C1
# 446    C2
# 67     C1
# 192    C1
#        ..
# 264    C1
# 43     C1
# 581    C2
# 701    C2
# 707    C2
# Name: Target, Length: 752, dtype: object

# %%
def getModel():
 return DecisionTreeClassifier(max_depth=6)

# %%
X_train,X_teste,y_train,y_teste = train_test_split(X.values,y.values,test_size = 0.2)


model = getModel().fit(X_train,y_train)

model.score(X_teste,y_teste)
# Out:
# 0.9933774834437086

# %%
cross_val = cross_val_score(getModel(), X, y, cv=10)

cross_val.mean()
# Out:
# 0.9879999999999999

# %%
plt.figure(figsize=(250,120))
plot_tree(model,fontsize=50)
# Out:
# [Text(0.44711538461538464, 0.9285714285714286, 'X[0] <= 0.625\ngini = 0.499\nsamples = 601\nvalue = [289, 312]'),
#  Text(0.25, 0.7857142857142857, 'X[1] <= 0.185\ngini = 0.339\nsamples = 347\nvalue = [272, 75]'),
#  Text(0.21153846153846154, 0.6428571428571429, 'gini = 0.0\nsamples = 51\nvalue = [0, 51]'),
#  Text(0.28846153846153844, 0.6428571428571429, 'X[1] <= 0.949\ngini = 0.149\nsamples = 296\nvalue = [272, 24]'),
#  Text(0.15384615384615385, 0.5, 'X[0] <= 0.606\ngini = 0.029\nsamples = 275\nvalue = [271, 4]'),
#  Text(0.07692307692307693, 0.35714285714285715, 'X[1] <= 0.933\ngini = 0.008\nsamples = 265\nvalue = [264, 1]'),
#  Text(0.038461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 260\nvalue = [260, 0]'),
#  Text(0.11538461538461539, 0.21428571428571427, 'X[1] <= 0.936\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.07692307692307693, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
predicoes = cross_val_predict(getModel(), X.values, y, cv=10)

cm = confusion_matrix(y,predicoes)

cm_df = pd.DataFrame(cm)

cm_df
# Out:
#      0    1
# 0  348    8
# 1    5  391
